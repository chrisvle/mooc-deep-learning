# %%
import time
import numpy as np
start_time = time.time()

import __init__

X = np.loadtxt("all142.txt")
Y = __init__.bh_sne(X)
print("--- %s seconds ---" % (time.time() - start_time))
print Y
# Out:
# --- 123.729568005 seconds ---
# [[  4.48421272 -30.47808558]
#  [  4.45770628 -30.44666965]
#  [  4.4763253  -30.48486821]
#  ...,
#  [ 27.11881758  27.29040586]
#  [-15.5546267    6.38022975]
#  [ 34.61896327 -43.75864891]]

# %%
import time
import numpy as np
start_time = time.time()

import tsne

X = np.loadtxt("all142.txt")
Y = tsne.tsne(X)
print("--- %s seconds ---" % (time.time() - start_time))
print Y
# Out:
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point  0  of  14058 ...
# Computing P-values for point  100  of  14058 ...
# Computing P-values for point  200  of  14058 ...
# Computing P-values for point  300  of  14058 ...
# Computing P-values for point  400  of  14058 ...
# Computing P-values for point  500  of  14058 ...
# Computing P-values for point  600  of  14058 ...
# Computing P-values for point  700  of  14058 ...
# Computing P-values for point  800  of  14058 ...
# Computing P-values for point  900  of  14058 ...
# Computing P-values for point  1000  of  14058 ...
# Computing P-values for point  1100  of  14058 ...
# Computing P-values for point  1200  of  14058 ...
# Computing P-values for point  1300  of  14058 ...
# Computing P-values for point  1400  of  14058 ...
# Computing P-values for point  1500  of  14058 ...
# Computing P-values for point  1600  of  14058 ...
# Computing P-values for point  1700  of  14058 ...
# Computing P-values for point  1800  of  14058 ...
# Computing P-values for point  1900  of  14058 ...
# Computing P-values for point  2000  of  14058 ...
# Computing P-values for point  2100  of  14058 ...
# Computing P-values for point  2200  of  14058 ...
# Computing P-values for point  2300  of  14058 ...
# Computing P-values for point  2400  of  14058 ...
# Computing P-values for point  2500  of  14058 ...
# Computing P-values for point  2600  of  14058 ...
# Computing P-values for point  2700  of  14058 ...
# Computing P-values for point  2800  of  14058 ...
# Computing P-values for point  2900  of  14058 ...
# Computing P-values for point  3000  of  14058 ...
# Computing P-values for point  3100  of  14058 ...
# Computing P-values for point  3200  of  14058 ...
# Computing P-values for point  3300  of  14058 ...
# Computing P-values for point  3400  of  14058 ...
# Computing P-values for point  3500  of  14058 ...
# Computing P-values for point  3600  of  14058 ...
# Computing P-values for point  3700  of  14058 ...
# Computing P-values for point  3800  of  14058 ...
# Computing P-values for point  3900  of  14058 ...
# Computing P-values for point  4000  of  14058 ...
# Computing P-values for point  4100  of  14058 ...
# Computing P-values for point  4200  of  14058 ...
# Computing P-values for point  4300  of  14058 ...
# Computing P-values for point  4400  of  14058 ...
# Computing P-values for point  4500  of  14058 ...
# Computing P-values for point  4600  of  14058 ...
# Computing P-values for point  4700  of  14058 ...
# Computing P-values for point  4800  of  14058 ...
# Computing P-values for point  4900  of  14058 ...
# Computing P-values for point  5000  of  14058 ...
# Computing P-values for point  5100  of  14058 ...
# Computing P-values for point  5200  of  14058 ...
# Computing P-values for point  5300  of  14058 ...
# Computing P-values for point  5400  of  14058 ...
# Computing P-values for point  5500  of  14058 ...
# Computing P-values for point  5600  of  14058 ...
# Computing P-values for point  5700  of  14058 ...
# Computing P-values for point  5800  of  14058 ...
# Computing P-values for point  5900  of  14058 ...
# Computing P-values for point  6000  of  14058 ...
# Computing P-values for point  6100  of  14058 ...
# Computing P-values for point  6200  of  14058 ...
# Computing P-values for point  6300  of  14058 ...
# Computing P-values for point  6400  of  14058 ...
# Computing P-values for point  6500  of  14058 ...
# Computing P-values for point  6600  of  14058 ...
# Computing P-values for point  6700  of  14058 ...
# Computing P-values for point  6800  of  14058 ...
# Computing P-values for point  6900  of  14058 ...
# Computing P-values for point  7000  of  14058 ...
# Computing P-values for point  7100  of  14058 ...
# Computing P-values for point  7200  of  14058 ...
# Computing P-values for point  7300  of  14058 ...
# Computing P-values for point  7400  of  14058 ...
# Computing P-values for point  7500  of  14058 ...
# Computing P-values for point  7600  of  14058 ...
# Computing P-values for point  7700  of  14058 ...
# Computing P-values for point  7800  of  14058 ...
# Computing P-values for point  7900  of  14058 ...
# Computing P-values for point  8000  of  14058 ...
# Computing P-values for point  8100  of  14058 ...
# Computing P-values for point  8200  of  14058 ...
# Computing P-values for point  8300  of  14058 ...
# Computing P-values for point  8400  of  14058 ...
# Computing P-values for point  8500  of  14058 ...
# Computing P-values for point  8600  of  14058 ...
# Computing P-values for point  8700  of  14058 ...
# Computing P-values for point  8800  of  14058 ...
# Computing P-values for point  8900  of  14058 ...
# Computing P-values for point  9000  of  14058 ...
# Computing P-values for point  9100  of  14058 ...
# Computing P-values for point  9200  of  14058 ...
# Computing P-values for point  9300  of  14058 ...
# Computing P-values for point  9400  of  14058 ...
# Computing P-values for point  9500  of  14058 ...
# Computing P-values for point  9600  of  14058 ...
# Computing P-values for point  9700  of  14058 ...
# Computing P-values for point  9800  of  14058 ...
# Computing P-values for point  9900  of  14058 ...
# Computing P-values for point  10000  of  14058 ...
# Computing P-values for point  10100  of  14058 ...
# Computing P-values for point  10200  of  14058 ...
# Computing P-values for point  10300  of  14058 ...
# Computing P-values for point  10400  of  14058 ...
# Computing P-values for point  10500  of  14058 ...
# Computing P-values for point  10600  of  14058 ...
# Computing P-values for point  10700  of  14058 ...
# Computing P-values for point  10800  of  14058 ...
# Computing P-values for point  10900  of  14058 ...
# Computing P-values for point  11000  of  14058 ...
# Computing P-values for point  11100  of  14058 ...
# Computing P-values for point  11200  of  14058 ...
# Computing P-values for point  11300  of  14058 ...
# Computing P-values for point  11400  of  14058 ...
# Computing P-values for point  11500  of  14058 ...
# Computing P-values for point  11600  of  14058 ...
# Computing P-values for point  11700  of  14058 ...
# Computing P-values for point  11800  of  14058 ...
# Computing P-values for point  11900  of  14058 ...
# Computing P-values for point  12000  of  14058 ...
# Computing P-values for point  12100  of  14058 ...
# Computing P-values for point  12200  of  14058 ...
# Computing P-values for point  12300  of  14058 ...
# Computing P-values for point  12400  of  14058 ...
# Computing P-values for point  12500  of  14058 ...
# Computing P-values for point  12600  of  14058 ...
# Computing P-values for point  12700  of  14058 ...
# Computing P-values for point  12800  of  14058 ...
# Computing P-values for point  12900  of  14058 ...
# Computing P-values for point  13000  of  14058 ...
# Computing P-values for point  13100  of  14058 ...
# Computing P-values for point  13200  of  14058 ...
# Computing P-values for point  13300  of  14058 ...
# Computing P-values for point  13400  of  14058 ...
# Computing P-values for point  13500  of  14058 ...
# Computing P-values for point  13600  of  14058 ...
# Computing P-values for point  13700  of  14058 ...
# Computing P-values for point  13800  of  14058 ...
# Computing P-values for point  13900  of  14058 ...
# Computing P-values for point  14000  of  14058 ...
# 0
# end of iter
# 1
# end of iter
# 2
# end of iter
# 3
# end of iter
# 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-528f97fbc6cb> in <module>()
#       6
#       7 X = np.loadtxt("all142.txt")
# ----> 8 Y = tsne.tsne(X)
#       9 print("--- %s seconds ---" % (time.time() - start_time))
#      10 print Y
#
# /Users/Chris/GitHub/deeplearnEDU/khanRNN/tsne.pyc in tsne(X, no_dims, initial_dims, perplexity)
#     136
#     137                 # # Compute gradient
# --> 138                 PQ = P - Q;
#     139                 for i in range(n):
#     140                         dY[i,:] = Math.sum(Math.tile(PQ[:,i] * num[:,i], (no_dims, 1)).T * (Y[i,:] - Y), 0);
#
# KeyboardInterrupt:

# %%
import time
import numpy as np
start_time = time.time()

from sklearn import manifold

X = np.loadtxt("all142.txt")
t = manifold.TSNE()
np.set_printoptions(suppress=True)
Y = t.fit_transform(X)
print Y
print("--- %s seconds ---" % (time.time() - start_time))
